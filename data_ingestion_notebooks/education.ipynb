# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings
from uuid import uuid4
import chromadb
from langchain_chroma import Chroma
from dotenv import load_dotenv
import os
from openai import OpenAI

load_dotenv()
api_key = os.getenv("API_KEY")
weather_api = os.getenv("WEATHER_API")
tavily_api = os.getenv("TAVILY_API")
client = OpenAI(api_key=api_key)

# %%
def data_refinement(user_query):
    client = OpenAI(api_key=api_key)
    completion = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": "You are a helpful Educational assistant."},
            {
            "role": "system",
            "content": f"""I am going to ask you a question and my question is {user_query}, which I would like you to answer"
            "based only on the provided context"
            "If there is not enough information in the user question ask for more information to answer the question,"
            "Dont say i dont know the answer make"
            "Break your answer up into nicely readable paragraphs".
            "Make the result in maximum 2 lies"
            """,
            }
        ]
    )
    result = completion.choices[0].message.content
    return result

# %%
data_refinement("Hi")
data_refinement("Thanks")
# Out:
# 'Sure! I appreciate your gratitude. If you have any specific questions or need assistance with something, feel free to ask!'

# %%
from tavily import TavilyClient
from langchain.adapters.openai import convert_openai_messages
from langchain_openai import ChatOpenAI

def researcher_agent(query):
    client = TavilyClient(api_key=tavily_api)
    # Step 2. Executing the search query and getting the results
    content = client.search(query=query, search_depth="advanced")["results"]
    
    # Step 3. Setting up the OpenAI prompts
    prompt = [{
        "role": "system",
        "content":  f'You are an AI critical thinker research assistant. '\
                    f'Your sole purpose is to write well written, critically acclaimed,'\
                    f'objective and structured reports on given text.'
    }, {
        "role": "user",
        "content": f'Information: """{content}"""\n\n' \
                   f'Using the above information, answer the following'\
                   f'query: "{query}" in a detailed report --'\
                   f'Please use MLA format and markdown syntax.'
    }]
    
    # Step 4. Running OpenAI through Langchain
    lc_messages = convert_openai_messages(prompt)
    report = ChatOpenAI(model='gpt-4o',openai_api_key=api_key).invoke(lc_messages).content
    return report

# %%
res_ans = researcher_agent("could you develop a well study plan for data analystist as my carrier")

# %%
print(res_ans)
# Out:
# # Developing a Study Plan for a Career as a Data Analyst
#
# ## Introduction
#
# Embarking on a career as a data analyst requires a structured approach to learning and skill acquisition. This report outlines a comprehensive study plan designed to equip aspiring data analysts with the necessary skills and knowledge to succeed in this dynamic field. Drawing from various resources, this guide will provide a step-by-step plan, emphasizing flexibility, self-discipline, and the importance of practical experience.
#
# ## Step 1: Define Career Goals and Timeline
#
# Before diving into specific skills and courses, it is crucial to establish clear career goals and a timeline ([Data Analyst 2024](https://www.datacamp.com/blog/how-to-become-a-data-analyst)). Consider the following:
#
# - **Short-term Goals:** Gain foundational knowledge in data analysis tools and techniques.
# - **Long-term Goals:** Develop expertise in a specialized area of data analysis or aim for leadership roles.
#
# ## Step 2: Core Areas of Learning
#
# The data analyst learning path consists of three main areas: data querying, data analysis, and data presentation ([365 Data Science](https://365datascience.com/career-advice/career-guides/how-to-become-a-data-analyst/)).
#
# ### Data Querying
#
# - **Key Skill:** Proficiency in SQL is essential, as it is mentioned in over 50% of job postings for data analysts.
# - **Resources:** Online courses, tutorials, and books focused on SQL.
#
# ### Data Analysis
#
# - **Key Skills:** Understanding of statistical methods and the ability to use software tools like Python or R.
# - **Resources:** Enroll in online courses or bootcamps that offer hands-on experience with data analysis.
#
# ### Data Presentation
#
# - **Key Skills:** Ability to communicate insights effectively using data visualization tools such as Tableau or Power BI.
# - **Resources:** Practice creating reports and dashboards through project-based learning.
#
# ## Step 3: Develop a Data Analysis Plan
#
# Creating a data analysis plan is crucial for structuring your study and practice ([CRENC eLearn](https://learn.crenc.org/how-to-create-a-data-analysis-plan/)). This plan should include:
#
# - **Variable Summarization:** Outline the variables you will analyze and the methods you will use.
# - **Statistics Selection:** Decide on the statistical methods best suited for your data.
# - **Missing Data Analysis:** Plan for handling missing data in your analyses.
#
# ## Step 4: Engage in Self-Study and Use Learning Resources
#
# Self-study is an effective way to develop essential skills ([Data Analyst Guide](https://www.dataanalyst.com/blog/how-to-become-a-data-analyst-a-step-by-step-guide)). Utilize the following resources:
#
# - **Books:** Covering both introductory and advanced topics in data analysis.
# - **Blogs and Online Articles:** Stay updated on industry trends and best practices.
# - **Mobile Courses:** Take advantage of platforms like DataCamp for on-the-go learning ([DataCamp](https://www.datacamp.com/blog/how-to-become-a-data-analyst)).
#
# ## Step 5: Build a Portfolio
#
# As you progress, focus on creating a portfolio that showcases your skills and projects ([Data Analyst 2024](https://www.datacamp.com/blog/how-to-become-a-data-analyst)). Include:
#
# - **Project Work:** Demonstrate your ability to apply data analysis techniques to real-world problems.
# - **Domain Knowledge:** Highlight any specialized knowledge in particular business areas.
#
# ## Conclusion
#
# Pursuing a career as a data analyst requires a blend of structured learning, practical experience, and continuous self-improvement. By following this study plan, aspiring data analysts can build a solid foundation, adapt to industry demands, and position themselves for success in this evolving field. Remember, the key to success lies in perseverance, curiosity, and a commitment to lifelong learning.

# %%
data_refinement("I am a high school grad looking for self paced cource to learn to earn good money for my family what procession should i choose my area of interest is problem solving")
# Out:
# 'Given your interest in problem solving, consider pursuing a career in fields such as software development, data analysis, or project management, all of which offer self-paced online courses. These professions are in high demand and can provide a strong financial foundation for your family.'

# %%
def data_refinement_1(user_query):
    client = OpenAI(api_key=api_key)
    completion = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": "You are a helpful Educational assistant will answer based on user query."},
            {
                "role": "system",
                "content": (
                    f"User query for Assesment: {user_query},"
                    "I am going to ask you to create an assessment consisting of 100 marks with 20 questions, "
                    "including 15 multiple-choice questions (MCQs) and 2 theory questions. "
                    "The assessment should be structured as follows:\n\n"
                    "### Assessment Structure:\n"
                    "- **Total Questions**: 20\n"
                    "- **Total Marks**: 100\n"
                    "- **MCQs**: 15 questions, each worth 4 marks (15 x 4 = 60 marks)\n"
                    "- **Theory Questions**: 2 questions, each worth 15 marks (2 x 15 = 30 marks)\n"
                    "- **Remaining Questions**: 3 questions, 2 worth 3 marks and 1 worth 4 marks. (9 + 1 = 10 marks)\n\n"
                    "### Example Format:\n\n"
                    "#### Section A: Multiple Choice Questions (MCQs)\n"
                    "(Each question carries 4 marks)\n\n"
                    "1. Sample Question 1\n"
                    "   - a) Option 1\n"
                    "   - b) Option 2\n"
                    "   - c) Option 3\n"
                    "   - d) Option 4\n\n"
                    "(Continue with the rest...)\n\n"
                    "#### Section B: Theory Questions\n"
                    "(Each question carries 15 marks)\n\n"
                    "16. Sample Theory Question 1\n"
                    "17. Sample Theory Question 2\n\n"
                    "#### Section C: Additional Questions\n"
                    "(Distribute remaining 9-10 marks)\n\n"
                    "18. Sample question worth 3 marks\n"
                    "19. Sample question worth 3 marks\n"
                    "20. Sample question worth 4 marks\n"
                ),
            },
        ]
    )
    result = completion.choices[0].message.content
    return result

# %%
print(data_refinement_1("Give me an assesment question for data sciencist"))
# Out:
# ### Data Scientist Assessment
#
# #### Total Questions: 20
# #### Total Marks: 100
#
# ---
#
# ### Section A: Multiple Choice Questions (MCQs)
# (Each question carries 4 marks)
#
# 1. Which of the following is a common method of regularization in machine learning?
#    - a) Ridge Regression
#    - b) K-means Clustering
#    - c) PCA
#    - d) Random Forests
#
# 2. What is the main purpose of the 'fit' method in machine learning?
#    - a) To optimize parameters based on training data
#    - b) To predict outcomes
#    - c) To visualize data
#    - d) To evaluate model performance
#
# 3. In a confusion matrix, which of the following metrics is NOT derived from it?
#    - a) Precision
#    - b) Recall
#    - c) Mean Squared Error
#    - d) F1 Score
#
# 4. Which of the following algorithms is used for classification tasks?
#    - a) Linear Regression
#    - b) Decision Trees
#    - c) k-Nearest Neighbors
#    - d) Both b and c
#
# 5. What does PCA stand for in data analysis?
#    - a) Principal Component Analysis
#    - b) Principal Component Algorithm
#    - c) Predictive Component Analysis
#    - d) Proven Component Analysis
#
# 6. Which of the following libraries is commonly used for data manipulation in Python?
#    - a) NumPy
#    - b) Matplotlib
#    - c) Pandas
#    - d) Scikit-learn
#
# 7. What type of data structure is a DataFrame in Pandas?
#    - a) 1-dimensional array
#    - b) List
#    - c) 2-dimensional tabular data
#    - d) Dictionary
#
# 8. In a neural network, what is the role of the activation function?
#    - a) Adjust the weights
#    - b) Introduce non-linearity
#    - c) Process inputs
#    - d) None of the above
#
# 9. Which evaluation metric is best used for imbalanced classification problems?
#    - a) Accuracy
#    - b) F1 Score
#    - c) Mean Absolute Error
#    - d) R-squared
#
# 10. What type of machine learning is used when the output labels are known?
#     - a) Unsupervised learning
#     - b) Reinforcement learning
#     - c) Supervised learning
#     - d) Semi-supervised learning
#
# 11. Which of the following techniques can be used for feature selection?
#     - a) Forward Selection
#     - b) Backward Elimination
#     - c) Lasso Regression
#     - d) All of the above
#
# 12. In time series analysis, what does the term 'seasonality' refer to?
#     - a) The trend over time
#     - b) Random variation
#     - c) Recurrent patterns at regular intervals
#     - d) Unpredictable elements in data
#
# 13. What is the main advantage of using Random Forest over decision trees?
#     - a) Higher interpretability
#     - b) Reduced overfitting
#     - c) Faster computation
#     - d) Simplicity
#
# 14. In exploratory data analysis, which type of plot is best for visualizing the distribution of a continuous variable?
#     - a) Bar plot
#     - b) Box plot
#     - c) Line plot
#     - d) Scatter plot
#
# 15. Which of the following is a hyperparameter in a machine learning model?
#     - a) Weights
#     - b) Learning Rate
#     - c) Output
#     - d) Predictions
#
# ---
#
# ### Section B: Theory Questions
# (Each question carries 15 marks)
#
# 16. Explain the difference between supervised and unsupervised learning. Provide examples of algorithms used in each category and discuss their applications.
#
# 17. Describe the steps involved in the data science workflow from data collection to model deployment. Highlight the importance of each step and any tools or techniques that may be used.
#
# ---
#
# ### Section C: Additional Questions
# (Distribute remaining 9-10 marks)
#
# 18. Describe the importance of data cleaning and preprocessing in a data science project. (3 marks)
#
# 19. What are outliers, and how can they affect the results of a machine learning model? Discuss one method to handle outliers. (3 marks)
#
# 20. What is the purpose of cross-validation in machine learning? Explain the concept briefly. (4 marks)
